# %% [markdown]
# #### Foundations

# %% [markdown]
# - What is RAG
# - Limitations of LLMs
# - Embeddings
# - Vector databases vs traditional DBs

# %% [markdown]
# - Difference between LangChain and LlamaIndex
# - Where LlamaIndex fits in AI stack

# %% [markdown]
# ### LlamaIndex Core Architecture

# %% [markdown]
# - Key Components
#   - Documents
#   - Nodes
#   - Indexes
#   - Query Engine
#   - Retriever
#   - Response Synthesizer

# %% [markdown]
# - Data Flow Understanding
#   - Raw Data → Loader → Nodes → Index → Retriever → LLM → Response

# %% [markdown]
# ### Data Ingestion Layer

# %% [markdown]
# - Loaders (Connectors)
#   - PDFs, CSV, JSON, APIs, databases
#   - Custom loaders
# - Node Parsing
#   - Chunking strategies
#     - Fixed size
#     - Semantic chunking
#   - Metadata extraction
# - Transformations
#   - Cleaning text
#   - Structuring documents

# %% [markdown]
# ### Indexing Strategies
# - Types of Indexes
#   - Vector Store Index
#   - Tree Index
#   - Keyword Table Index
#   - List Index

# %% [markdown]
# #### When to Use What
# - Semantic search → Vector
# - Hierarchical reasoning → Tree
# - Exact lookup → Keyword

# %% [markdown]
# ### Retrieval Systems

# %% [markdown]
# - Retrievers
#   - Basic retriever
#   - Similarity search
#   - Hybrid search (keyword + vector)
# - Advanced Retrieval
#   - Metadata filtering
#   - Recursive retrieval
#   - Auto-retrieval
# -  Ranking
#    - Re-ranking strategies
#    - Score-based filtering

# %% [markdown]
# ### Query Engine & Response Generation

# %% [markdown]
# - Query Engine
#   - Query pipelines
#   - Query transformations
# -  Response Modes
#    - Refine
#    - Compact
#    - Tree summarize
# - Prompting
#   - Custom prompts
#   - Template engineering

# %% [markdown]
# ### Embeddings & Vector Stores
# - Embeddings
#   - OpenAI / HuggingFace embeddings
#   - Choosing embedding models
# - Vector Databases
#   - FAISS
#   - Chroma
#   - Pinecone
#   - Weaviate
# - Learn:
#   - Tradeoffs (speed, cost, accuracy)
#
# - Build:
#   - Plug LlamaIndex into different vector DBs

# %% [markdown]
# ### Advanced RAG Techniques

# %% [markdown]
# - Retrieval Improvements
#   - Query rewriting
#   - Multi-step retrieval
#   - Context compression
# - Fusion Techniques
#   - Ensemble retrievers
#   - Multi-index querying
# - Evaluation
#   - Precision / Recall in RAG
#   - Benchmarking answers
# - Build:
#   - High-accuracy RAG system

# %% [markdown]
# ### Agents with LlamaIndex

# %% [markdown]
# - Agent Concepts
#   - Tool usage
#   - Decision-making loop
# - Tools in LlamaIndex
#   - Query engines as tools
#   - External APIs as tools
# - Multi-tool Agents
#   - Router agents
#   - Function calling
# - Build:
#   - Agent that:
#     - Queries documents
#     - Calls APIs
#     - Makes decisions

# %% [markdown]
# ### Memory & Context Management

# %% [markdown]
# - Types of Memory
#   - Chat memory
#   - Vector memory
#   - Long-term memory
# - Context Optimization
#   - Token limits
#   - Context pruning
# - Build:
#   - Conversational RAG chatbot

# %% [markdown]
# ### Streaming & Real-Time Systems

# %% [markdown]
# - Streaming Responses
#   - Token streaming
# - Real-Time Pipelines
#   - Handling live data
# - Build:
#   - Live chat interface

# %% [markdown]
# ### LlamaIndex + Backend Systems
