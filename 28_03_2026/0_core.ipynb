# %% [markdown]
# LlamaIndex = Data → Index → Query

# %% [markdown]
# **That’s the whole philosophy.**
# - You are not building chains
# - You are building a searchable knowledge system

# %% [markdown]
# ____
# ____

# %% [markdown]
# | LangChain       | LlamaIndex                 |
# | --------------- | -------------------------- |
# | Document Loader | Data Loader                |
# | Text Splitter   | Node Parser                |
# | Embeddings      | Embeddings                 |
# | Vector DB       | Index + Storage            |
# | Retriever       | Retriever                  |
# | Chain           | Query Engine               |
# | Agent           | (Less important)           |
# | Memory          | (Handled via index itself) |

# %% [markdown]
# ### What You Should Study FIRST (Order)

# %% [markdown]
# - Documents & Nodes
# - Node Parsing
# - Vector Index
# - StorageContext
# - Retriever
# - QueryEngine
# - Response Synthesizer
# - Advanced Retrieval
# - Composable Graphs
