# %% [markdown]
# This replaces a lot of LangChain complexity.
#
# Topics:
#
# - Basic retriever
# - Similarity search
# - Hybrid search
# - Metadata filtering
#
#  Key idea:
#
# - You don’t query index directly → you use a retriever
