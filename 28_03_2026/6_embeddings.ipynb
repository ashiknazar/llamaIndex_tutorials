# %% [markdown]
# ### Embeddings (Same concept, different usage)

# %% [markdown]
# - Embedding models
# - Custom embeddings
# - Local vs API embeddings
#
#  Used internally for:
#
# - Node similarity
# - Retrieval
