# %% [markdown]
# ### 1. Data Loaders (Ingestion Layer)
# -  What it actually does
#
# Loaders convert raw data → LlamaIndex Documents
#
# - Sources:
#   - PDFs
#   - Logs
#   - APIs
#   - Databases

# %% [markdown]
# ___

# %% [markdown]
# - Example: Load text / logs

# %% [markdown]
# ```python
# from llama_index.core import SimpleDirectoryReader
#
# documents = SimpleDirectoryReader("data").load_data()

# %% [markdown]
# ___
# ___

# %% [markdown]
# - Loader = Adapter that converts ANY data source → standardized Document objects
#
# #### The Standard Output
#
# Everything must become this:
#
# ```python
# Document(
#     text="actual content",
#     metadata={"key": "value"}
# )

# %% [markdown]
# ___

# %% [markdown]
# ### Types of Data Loaders

# %% [markdown]
# - File-Based Loaders
#
# Examples:
#   - PDFs
#   - TXT
#   - CSV
#   - Markdown

# %% [markdown]
# ___

# %% [markdown]
# ```python
#
# from llama_index.core import SimpleDirectoryReader, VectorStoreIndex
# documents = SimpleDirectoryReader(
#     input_files=["demo.pdf"]
# ).load_data()
